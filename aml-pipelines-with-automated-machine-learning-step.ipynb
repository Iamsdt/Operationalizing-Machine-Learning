# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.20.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-138142
# aml-quickstarts-138142
# southcentralus
# 9e65f93e-bdd8-437b-b1e8-0647cd6098f7

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'project2'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: project2,
# Workspace: quick-starts-ws-138142)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "project2"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

# showing error two error
"""
TypeError: wait_for_completion() got an unexpected keyword argument 'min_node_count'
TypeError: wait_for_completion() got an unexpected keyword argument 'timeout_in_minutes'
"""
# compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
compute_target.wait_for_completion(show_output=True)

# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
#
# Running

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "Bank-marketing"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [64c101ae][fa4e44e0-47cd-48a5-87d7-b75e8f445e72], (This step will run and generate new outputs)
# Submitted PipelineRun 948acb6c-9eb4-4633-a19e-430067bb3dd3
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/project2/runs/948acb6c-9eb4-4633-a19e-430067bb3dd3?wsid=/subscriptions/9e65f93e-bdd8-437b-b1e8-0647cd6098f7/resourcegroups/aml-quickstarts-138142/workspaces/quick-starts-ws-138142

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 948acb6c-9eb4-4633-a19e-430067bb3dd3
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/project2/runs/948acb6c-9eb4-4633-a19e-430067bb3dd3?wsid=/subscriptions/9e65f93e-bdd8-437b-b1e8-0647cd6098f7/resourcegroups/aml-quickstarts-138142/workspaces/quick-starts-ws-138142
# PipelineRun Status: Running
#
#
# StepRunId: 92d468e0-d6d8-4216-91b4-0ec68f93c8a6
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/project2/runs/92d468e0-d6d8-4216-91b4-0ec68f93c8a6?wsid=/subscriptions/9e65f93e-bdd8-437b-b1e8-0647cd6098f7/resourcegroups/aml-quickstarts-138142/workspaces/quick-starts-ws-138142
# StepRun( automl_module ) Status: NotStarted
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': '92d468e0-d6d8-4216-91b4-0ec68f93c8a6', 'target': 'project2', 'status': 'Completed', 'startTimeUtc': '2021-02-08T13:47:17.225831Z', 'endTimeUtc': '2021-02-08T14:21:19.886892Z', 'properties': {'ContentSnapshotId': 'db59d504-8b42-4ead-94ef-64b85a25a6ae', 'StepType': 'AutoMLStep', 'azureml.moduleid': 'fa4e44e0-47cd-48a5-87d7-b75e8f445e72', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '64c101ae', 'azureml.pipelinerunid': '948acb6c-9eb4-4633-a19e-430067bb3dd3', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'project2', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "9e65f93e-bdd8-437b-b1e8-0647cd6098f7", "resource_group": "aml-quickstarts-138142", "workspace_name": "quick-starts-ws-138142", "region": "southcentralus", "compute_target": "project2", "spark_service": null, "azure_service": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 5, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["KNN", "SGD", "LinearSVM", "LogisticRegression", "DecisionTree", "RandomForest", "SVM", "LightGBM", "TensorFlowLinearClassifier", "BernoulliNaiveBayes", "MultinomialNaiveBayes", "GradientBoosting", "ExtremeRandomTrees", "TensorFlowDNN", "AveragedPerceptronClassifier", "XGBoostClassifier"], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_DS3_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "SDK-1.13.0", "environment_label": null, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "_local_managed_run_id": null, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"55f75096-429c-48de-8711-3a5f08b0bada\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': 'db59d504-8b42-4ead-94ef-64b85a25a6ae', 'SetupRunId': '92d468e0-d6d8-4216-91b4-0ec68f93c8a6_setup', 'SetupRunContainerId': 'dcid.92d468e0-d6d8-4216-91b4-0ec68f93c8a6_setup', 'ClientSdkVersion': '1.20.0', 'FeaturizationRunJsonPath': 'featurizer_container.json', 'FeaturizationRunId': '92d468e0-d6d8-4216-91b4-0ec68f93c8a6_featurize', 'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampling": false, "dataset_cla ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '948acb6c-9eb4-4633-a19e-430067bb3dd3', 'status': 'Completed', 'startTimeUtc': '2021-02-08T13:46:58.382217Z', 'endTimeUtc': '2021-02-08T14:23:41.735941Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg138142.blob.core.windows.net/azureml/ExperimentRun/dcid.948acb6c-9eb4-4633-a19e-430067bb3dd3/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=DTjgYVEM%2B%2BgDKeigOxlm%2B6PPPyfEa1rFWrEA5%2B2rIsU%3D&st=2021-02-08T13%3A37%3A01Z&se=2021-02-08T21%3A47%3A01Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg138142.blob.core.windows.net/azureml/ExperimentRun/dcid.948acb6c-9eb4-4633-a19e-430067bb3dd3/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=bT32YPlDx36jK0ZbrjDdPFnm23%2FLOWcmxGpxQljl5zM%3D&st=2021-02-08T13%3A37%3A01Z&se=2021-02-08T21%3A47%3A01Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg138142.blob.core.windows.net/azureml/ExperimentRun/dcid.948acb6c-9eb4-4633-a19e-430067bb3dd3/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=RUs1rDrwJYoS2kbrUNMv%2B%2FRnv0FKkIllu0LXDkTxlmE%3D&st=2021-02-08T13%3A37%3A01Z&se=2021-02-08T21%3A47%3A01Z&sp=r'}, 'submittedBy': 'ODL_User 138142'}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/92d468e0-d6d8-4216-91b4-0ec68f93c8a6/metrics_data
# Downloaded azureml/92d468e0-d6d8-4216-91b4-0ec68f93c8a6/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  92d468e0-d6d8-4216-91b4-0ec68f93c8a6_27  \
# AUC_micro                                           [0.9790717991346616]
# average_precision_score_weighted                    [0.9521050203781521]
# f1_score_micro                                      [0.9113808801213961]
# precision_score_micro                               [0.9113808801213961]
# AUC_weighted                                        [0.9430421952886652]
# precision_score_weighted                            [0.9049425950747526]
# f1_score_macro                                       [0.757427390076644]
# recall_score_macro                                  [0.7369588049947485]
# balanced_accuracy                                   [0.7369588049947485]
# AUC_macro                                           [0.9430421952886652]
# average_precision_score_micro                       [0.9800640147014099]
# f1_score_weighted                                   [0.9073927516173796]
# matthews_correlation                                [0.5187332002422864]
# precision_score_macro                                [0.783893368131612]
# weighted_accuracy                                   [0.9546851633380424]
# average_precision_score_macro                       [0.8113142210601237]
# recall_score_weighted                               [0.9113808801213961]
# norm_macro_recall                                  [0.47391760998949706]
# recall_score_micro                                  [0.9113808801213961]
# accuracy                                            [0.9113808801213961]
# log_loss                                           [0.18224214673679842]
#
#                                  92d468e0-d6d8-4216-91b4-0ec68f93c8a6_30  \
# AUC_micro                                           [0.9788862050147255]
# average_precision_score_weighted                    [0.9517838306968476]
# f1_score_micro                                      [0.9128983308042489]
# precision_score_micro                               [0.9128983308042489]
# AUC_weighted                                        [0.9424920394111663]
# precision_score_weighted                             [0.907019636133764]
# f1_score_macro                                      [0.7631470523778217]
# recall_score_macro                                   [0.743733872745426]
# balanced_accuracy                                    [0.743733872745426]
# AUC_macro                                           [0.9424920394111664]
# average_precision_score_micro                       [0.9798810767294689]
# f1_score_weighted                                   [0.9092974412848348]
# matthews_correlation                                [0.5296299768558868]
# precision_score_macro                               [0.7877194593684469]
# weighted_accuracy                                   [0.9548972899190897]
# average_precision_score_macro                       [0.8101845152999028]
# recall_score_weighted                               [0.9128983308042489]
# norm_macro_recall                                  [0.48746774549085203]
# recall_score_micro                                  [0.9128983308042489]
# accuracy                                            [0.9128983308042489]
# log_loss                                            [0.1816076074356531]
#
#                                  92d468e0-d6d8-4216-91b4-0ec68f93c8a6_35  \
# AUC_micro                                           [0.9793896578482595]
# average_precision_score_weighted                    [0.9530452472189251]
# f1_score_micro                                      [0.9147192716236722]
# precision_score_micro                               [0.9147192716236723]
# AUC_weighted                                         [0.943678486682338]
# precision_score_weighted                            [0.9093275652660812]
# f1_score_macro                                      [0.7693088121818761]
# recall_score_macro                                  [0.7506798222459327]
# balanced_accuracy                                   [0.7506798222459327]
# AUC_macro                                           [0.9436784866823378]
# average_precision_score_micro                       [0.9803548944425503]
# f1_score_weighted                                   [0.9114397543809099]
# matthews_correlation                                [0.5415601539975136]
# precision_score_macro                               [0.7924920300426865]
# weighted_accuracy                                   [0.9554458297121392]
# average_precision_score_macro                         [0.81527742273076]
# recall_score_weighted                               [0.9147192716236723]
# norm_macro_recall                                   [0.5013596444918653]
# recall_score_micro                                  [0.9147192716236723]
# accuracy                                            [0.9147192716236723]
# log_loss                                            [0.1801468505720253]
#
#                                  92d468e0-d6d8-4216-91b4-0ec68f93c8a6_40  \
# AUC_micro                                           [0.8880121396054628]
# average_precision_score_weighted                    [0.8011068409624182]
# f1_score_micro                                      [0.8880121396054628]
# precision_score_micro                               [0.8880121396054628]
# AUC_weighted                                                       [0.5]
# precision_score_weighted                             [0.788565560086672]
# f1_score_macro                                      [0.4703423886834914]
# recall_score_macro                                                 [0.5]
# balanced_accuracy                                                  [0.5]
# AUC_macro                                                          [0.5]
# average_precision_score_micro                       [0.8445594902839405]
# f1_score_weighted                                   [0.8353395018439429]
# matthews_correlation                                               [0.0]
# precision_score_macro                               [0.4440060698027314]
# weighted_accuracy                                   [0.9843450583187134]
# average_precision_score_macro                                      [0.5]
# recall_score_weighted                               [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
# recall_score_micro                                  [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# log_loss                                            [0.3543630368390971]
#
#                                  92d468e0-d6d8-4216-91b4-0ec68f93c8a6_43  \
# AUC_micro                                           [0.9799325321623558]
# average_precision_score_weighted                    [0.9533568266187781]
# f1_score_micro                                      [0.9147192716236722]
# precision_score_micro                               [0.9147192716236723]
# AUC_weighted                                         [0.946511696832621]
# precision_score_weighted                            [0.9103232253680834]
# f1_score_macro                                      [0.7728538943905967]
# recall_score_macro                                   [0.757784613047771]
# balanced_accuracy                                    [0.757784613047771]
# AUC_macro                                            [0.946511696832621]
# average_precision_score_micro                       [0.9808658587584766]
# f1_score_weighted                                   [0.9121587214201567]
# matthews_correlation                                [0.5475350687797738]
# precision_score_macro                               [0.7907414139261637]
# weighted_accuracy                                    [0.953681902337382]
# average_precision_score_macro                       [0.8153003284979661]
# recall_score_weighted                               [0.9147192716236723]
# norm_macro_recall                                    [0.515569226095542]
# recall_score_micro                                  [0.9147192716236723]
# accuracy                                            [0.9147192716236723]
# log_loss                                           [0.17876970353900085]
#
#                                  92d468e0-d6d8-4216-91b4-0ec68f93c8a6_17  \
# AUC_micro                                           [0.8266878818092434]
# average_precision_score_weighted                    [0.9092142977033159]
# f1_score_micro                                      [0.7578148710166921]
# precision_score_micro                                [0.757814871016692]
# AUC_weighted                                        [0.8176955693001906]
# precision_score_weighted                            [0.8786265845652987]
# f1_score_macro                                      [0.6228713986894207]
# recall_score_macro                                   [0.738118392803887]
# balanced_accuracy                                    [0.738118392803887]
# AUC_macro                                           [0.8176955693001906]
# average_precision_score_micro                       [0.8048378329349242]
# f1_score_weighted                                   [0.7979350510186102]
# matthews_correlation                               [0.33102719022385396]
# precision_score_macro                               [0.6150467624289614]
# weighted_accuracy                                   [0.7627049737762107]
# average_precision_score_macro                       [0.7067777493615367]
# recall_score_weighted                                [0.757814871016692]
# norm_macro_recall                                  [0.47623678560777405]
# recall_score_micro                                   [0.757814871016692]
# accuracy                                             [0.757814871016692]
# log_loss                                             [0.563036624013174]
#
#                                  92d468e0-d6d8-4216-91b4-0ec68f93c8a6_13  \
# AUC_micro                                           [0.9758990146932517]
# average_precision_score_weighted                     [0.947605275820125]
# f1_score_micro                                      [0.9062215477996965]
# precision_score_micro                               [0.9062215477996965]
# AUC_weighted                                        [0.9308878256246675]
# precision_score_weighted                            [0.8929725418691179]
# f1_score_macro                                      [0.6650154684677185]
# recall_score_macro                                  [0.6227454260188535]
# balanced_accuracy                                   [0.6227454260188535]
# AUC_macro                                           [0.9308878256246677]
# average_precision_score_micro                       [0.9766643355999638]
# f1_score_weighted                                    [0.885603431576398]
# matthews_correlation                                [0.3976739324324451]
# precision_score_macro                                [0.822098675416211]
# weighted_accuracy                                   [0.9766010009385309]
# average_precision_score_macro                       [0.7985126174047921]
# recall_score_weighted                               [0.9062215477996965]
# norm_macro_recall                                  [0.24549085203770704]
# recall_score_micro                                  [0.9062215477996965]
# accuracy                                            [0.9062215477996965]
# log_loss                                           [0.33655623030329523]
#
#                                  92d468e0-d6d8-4216-91b4-0ec68f93c8a6_16  \
# AUC_micro                                            [0.851370702379335]
# average_precision_score_weighted                    [0.9231624473634359]
# f1_score_micro                                      [0.7781487101669197]
# precision_score_micro                               [0.7781487101669196]
# AUC_weighted                                        [0.8628643856500082]
# precision_score_weighted                            [0.8863600085760591]
# f1_score_macro                                       [0.645410435714802]
# recall_score_macro                                  [0.7625929198458081]
# balanced_accuracy                                   [0.7625929198458081]
# AUC_macro                                           [0.8628643856500082]
# average_precision_score_micro                       [0.8304955345473581]
# f1_score_weighted                                   [0.8137694475074928]
# matthews_correlation                                [0.3704234429659285]
# precision_score_macro                               [0.6306333079917985]
# weighted_accuracy                                   [0.7820107921266432]
# average_precision_score_macro                       [0.7308395904498144]
# recall_score_weighted                               [0.7781487101669196]
# norm_macro_recall                                   [0.5251858396916163]
# recall_score_micro                                  [0.7781487101669196]
# accuracy                                            [0.7781487101669196]
# log_loss                                            [0.5036289149208045]
#
#                                  92d468e0-d6d8-4216-91b4-0ec68f93c8a6_38  \
# AUC_micro                                           [0.9735100545499342]
# average_precision_score_weighted                    [0.9407230089760747]
# f1_score_micro                                      [0.9019726858877086]
# precision_score_micro                               [0.9019726858877086]
# AUC_weighted                                          [0.92522279460662]
# precision_score_weighted                            [0.8850573938766768]
# f1_score_macro                                      [0.6485444754527494]
# recall_score_macro                                  [0.6108800271187947]
# balanced_accuracy                                   [0.6108800271187947]
# AUC_macro                                             [0.92522279460662]
# average_precision_score_micro                       [0.9748002979411348]
# f1_score_weighted                                   [0.8801441659753338]
# matthews_correlation                               [0.36191338605668844]
# precision_score_macro                               [0.7953221206978213]
# weighted_accuracy                                   [0.9742431191368415]
# average_precision_score_macro                       [0.7690315367108689]
# recall_score_weighted                               [0.9019726858877086]
# norm_macro_recall                                   [0.2217600542375895]
# recall_score_micro                                  [0.9019726858877086]
# accuracy                                            [0.9019726858877086]
# log_loss                                           [0.21902016566918409]
#
#                                  92d468e0-d6d8-4216-91b4-0ec68f93c8a6_52  ...  \
# AUC_micro                                           [0.9785133588621192]  ...
# average_precision_score_weighted                    [0.9516039391635387]  ...
# f1_score_micro                                      [0.9101669195751139]  ...
# precision_score_micro                               [0.9101669195751139]  ...
# AUC_weighted                                        [0.9403465241077565]  ...
# precision_score_weighted                             [0.903605295208037]  ...
# f1_score_macro                                      [0.7541044776119402]  ...
# recall_score_macro                                  [0.7339070143948192]  ...
# balanced_accuracy                                   [0.7339070143948192]  ...
# AUC_macro                                           [0.9403465241077564]  ...
# average_precision_score_micro                       [0.9795183560465563]  ...
# f1_score_weighted                                   [0.9061241591737821]  ...
# matthews_correlation                                [0.5120524394053735]  ...
# precision_score_macro                               [0.7802371076593941]  ...
# weighted_accuracy                                   [0.9539274862816189]  ...
# average_precision_score_macro                       [0.8104647308730237]  ...
# recall_score_weighted                               [0.9101669195751139]  ...
# norm_macro_recall                                   [0.4678140287896384]  ...
# recall_score_micro                                  [0.9101669195751139]  ...
# accuracy                                            [0.9101669195751139]  ...
# log_loss                                           [0.18591848718388307]  ...
#
#                                  92d468e0-d6d8-4216-91b4-0ec68f93c8a6_1  \
# AUC_micro                                          [0.9781770788959222]
# average_precision_score_weighted                   [0.9505970434373063]
# f1_score_micro                                     [0.9071320182094081]
# precision_score_micro                              [0.9071320182094081]
# AUC_weighted                                       [0.9392346349984347]
# precision_score_weighted                           [0.8991976076061607]
# f1_score_macro                                     [0.7416848907681176]
# recall_score_macro                                 [0.7191727470931578]
# balanced_accuracy                                  [0.7191727470931578]
# AUC_macro                                          [0.9392346349984347]
# average_precision_score_micro                      [0.9791945367231853]
# f1_score_weighted                                  [0.9021127651963996]
# matthews_correlation                                [0.488678780261868]
# precision_score_macro                              [0.7723958081530135]
# weighted_accuracy                                  [0.9537972210153172]
# average_precision_score_macro                      [0.8065229883244922]
# recall_score_weighted                              [0.9071320182094081]
# norm_macro_recall                                 [0.43834549418631563]
# recall_score_micro                                 [0.9071320182094081]
# accuracy                                           [0.9071320182094081]
# log_loss                                           [0.1874363495858499]
#
#                                  92d468e0-d6d8-4216-91b4-0ec68f93c8a6_26  \
# AUC_micro                                           [0.9771930155820769]
# average_precision_score_weighted                    [0.9499966225005592]
# f1_score_micro                                      [0.9074355083459787]
# precision_score_micro                               [0.9074355083459787]
# AUC_weighted                                        [0.9350098268583507]
# precision_score_weighted                            [0.8935012190755486]
# f1_score_macro                                      [0.6969780573488569]
# recall_score_macro                                  [0.6554005116264423]
# balanced_accuracy                                   [0.6554005116264423]
# AUC_macro                                           [0.9350098268583507]
# average_precision_score_micro                       [0.9781626875518643]
# f1_score_weighted                                   [0.8929502722795345]
# matthews_correlation                               [0.43128813031641494]
# precision_score_macro                               [0.7992420189049403]
# weighted_accuracy                                   [0.9700089806001332]
# average_precision_score_macro                       [0.8063549152507894]
# recall_score_weighted                               [0.9074355083459787]
# norm_macro_recall                                   [0.3108010232528846]
# recall_score_micro                                  [0.9074355083459787]
# accuracy                                            [0.9074355083459787]
# log_loss                                            [0.3304940796991938]
#
#                                  92d468e0-d6d8-4216-91b4-0ec68f93c8a6_25  \
# AUC_micro                                           [0.9737535835092945]
# average_precision_score_weighted                    [0.9458396062576432]
# f1_score_micro                                      [0.8995447647951441]
# precision_score_micro                               [0.8995447647951441]
# AUC_weighted                                        [0.9261128616070851]
# precision_score_weighted                            [0.8849783769177578]
# f1_score_macro                                      [0.6044531098980928]
# recall_score_macro                                  [0.5763572827115832]
# balanced_accuracy                                   [0.5763572827115832]
# AUC_macro                                            [0.926112861607085]
# average_precision_score_micro                       [0.9749096479137287]
# f1_score_weighted                                   [0.8695793788973059]
# matthews_correlation                               [0.31289262190926104]
# precision_score_macro                               [0.8205384914463453]
# weighted_accuracy                                   [0.9797834745230228]
# average_precision_score_macro                       [0.7921758616931668]
# recall_score_weighted                               [0.8995447647951441]
# norm_macro_recall                                   [0.1527145654231663]
# recall_score_micro                                  [0.8995447647951441]
# accuracy                                            [0.8995447647951441]
# log_loss                                            [0.2236682000120795]
#
#                                  92d468e0-d6d8-4216-91b4-0ec68f93c8a6_55  \
# AUC_micro                                           [0.9785210036819478]
# average_precision_score_weighted                    [0.9514155002291758]
# f1_score_micro                                      [0.9119878603945372]
# precision_score_micro                               [0.9119878603945372]
# AUC_weighted                                         [0.940050606931223]
# precision_score_weighted                            [0.9066209162193739]
# f1_score_macro                                       [0.762847036773042]
# recall_score_macro                                  [0.7455894910965515]
# balanced_accuracy                                   [0.7455894910965515]
# AUC_macro                                           [0.9400506069312231]
# average_precision_score_micro                       [0.9795125449248038]
# f1_score_weighted                                   [0.9087915779135559]
# matthews_correlation                                [0.5282799529434207]
# precision_score_macro                               [0.7840916639346194]
# weighted_accuracy                                    [0.953300074491497]
# average_precision_score_macro                       [0.8098370387850273]
# recall_score_weighted                               [0.9119878603945372]
# norm_macro_recall                                  [0.49117898219310296]
# recall_score_micro                                  [0.9119878603945372]
# accuracy                                            [0.9119878603945372]
# log_loss                                            [0.2102222983549571]
#
#                                  92d468e0-d6d8-4216-91b4-0ec68f93c8a6_15  \
# AUC_micro                                           [0.9649975016176162]
# average_precision_score_weighted                    [0.9196485923032603]
# f1_score_micro                                      [0.8880121396054628]
# precision_score_micro                               [0.8880121396054628]
# AUC_weighted                                        [0.8870689287890828]
# precision_score_weighted                             [0.788565560086672]
# f1_score_macro                                      [0.4703423886834914]
# recall_score_macro                                                 [0.5]
# balanced_accuracy                                                  [0.5]
# AUC_macro                                           [0.8870689287890828]
# average_precision_score_micro                       [0.9652985118520028]
# f1_score_weighted                                   [0.8353395018439429]
# matthews_correlation                                               [0.0]
# precision_score_macro                               [0.4440060698027314]
# weighted_accuracy                                   [0.9843450583187134]
# average_precision_score_macro                       [0.6967351658846097]
# recall_score_weighted                               [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
# recall_score_micro                                  [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# log_loss                                            [0.2522022207719965]
#
#                                  92d468e0-d6d8-4216-91b4-0ec68f93c8a6_5  \
# AUC_micro                                          [0.9690201505476869]
# average_precision_score_weighted                    [0.931789278670738]
# f1_score_micro                                     [0.8980273141122913]
# precision_score_micro                              [0.8980273141122913]
# AUC_weighted                                       [0.9055385136899899]
# precision_score_weighted                           [0.8776483268190767]
# f1_score_macro                                     [0.6267980518745044]
# recall_score_macro                                 [0.5944489827673396]
# balanced_accuracy                                  [0.5944489827673396]
# AUC_macro                                            [0.90553851368999]
# average_precision_score_micro                      [0.9698335067802962]
# f1_score_weighted                                  [0.8736948918681039]
# matthews_correlation                               [0.3218901944130632]
# precision_score_macro                              [0.7742573139048909]
# weighted_accuracy                                  [0.9733976021303259]
# average_precision_score_macro                      [0.7405685120642169]
# recall_score_weighted                              [0.8980273141122913]
# norm_macro_recall                                  [0.1888979655346792]
# recall_score_micro                                 [0.8980273141122913]
# accuracy                                           [0.8980273141122913]
# log_loss                                          [0.24056577496369627]
#
#                                  92d468e0-d6d8-4216-91b4-0ec68f93c8a6_54  \
# AUC_micro                                           [0.9791838924567272]
# average_precision_score_weighted                    [0.9522617424320459]
# f1_score_micro                                      [0.9122913505311078]
# precision_score_micro                               [0.9122913505311078]
# AUC_weighted                                        [0.9437803674003931]
# precision_score_weighted                            [0.9070348410200512]
# f1_score_macro                                      [0.7639708800214947]
# recall_score_macro                                  [0.7469445046466869]
# balanced_accuracy                                   [0.7469445046466869]
# AUC_macro                                           [0.9437803674003931]
# average_precision_score_micro                       [0.9801765202461562]
# f1_score_weighted                                   [0.9091682165808672]
# matthews_correlation                                [0.5304371020063181]
# precision_score_macro                               [0.7848448881130385]
# weighted_accuracy                                   [0.9533424998077065]
# average_precision_score_macro                       [0.8116395163424088]
# recall_score_weighted                               [0.9122913505311078]
# norm_macro_recall                                  [0.49388900929337387]
# recall_score_micro                                  [0.9122913505311078]
# accuracy                                            [0.9122913505311078]
# log_loss                                            [0.1836210807960794]
#
#                                  92d468e0-d6d8-4216-91b4-0ec68f93c8a6_0  \
# AUC_micro                                           [0.979695082216353]
# average_precision_score_weighted                   [0.9531771295804466]
# f1_score_micro                                     [0.9116843702579667]
# precision_score_micro                              [0.9116843702579667]
# AUC_weighted                                       [0.9450464668693167]
# precision_score_weighted                           [0.9072720074188747]
# f1_score_macro                                     [0.7653697272147331]
# recall_score_macro                                 [0.7513392683482543]
# balanced_accuracy                                  [0.7513392683482543]
# AUC_macro                                          [0.9450464668693166]
# average_precision_score_micro                      [0.9806603102489483]
# f1_score_weighted                                  [0.9091539479147899]
# matthews_correlation                               [0.5323740218566827]
# precision_score_macro                              [0.7819118765348991]
# weighted_accuracy                                  [0.9514937218005303]
# average_precision_score_macro                      [0.8151093723721079]
# recall_score_weighted                              [0.9116843702579667]
# norm_macro_recall                                  [0.5026785366965085]
# recall_score_micro                                 [0.9116843702579667]
# accuracy                                           [0.9116843702579667]
# log_loss                                          [0.17775706110025447]
#
#                                  92d468e0-d6d8-4216-91b4-0ec68f93c8a6_37  \
# AUC_micro                                           [0.9797055823303346]
# average_precision_score_weighted                    [0.9536272740055581]
# f1_score_micro                                      [0.9116843702579667]
# precision_score_micro                               [0.9116843702579667]
# AUC_weighted                                        [0.9451400118922584]
# precision_score_weighted                            [0.9050318363975759]
# f1_score_macro                                      [0.7572938163705586]
# recall_score_macro                                  [0.7359455549442713]
# balanced_accuracy                                   [0.7359455549442713]
# AUC_macro                                           [0.9451400118922584]
# average_precision_score_micro                        [0.980657776389614]
# f1_score_weighted                                   [0.9075132403774469]
# matthews_correlation                                [0.5188485842832073]
# precision_score_macro                               [0.7852393780805413]
# weighted_accuracy                                   [0.9553155644458374]
# average_precision_score_macro                       [0.8171616074642105]
# recall_score_weighted                               [0.9116843702579667]
# norm_macro_recall                                  [0.47189110988854255]
# recall_score_micro                                  [0.9116843702579667]
# accuracy                                            [0.9116843702579667]
# log_loss                                           [0.17858324434463335]
#
#                                  92d468e0-d6d8-4216-91b4-0ec68f93c8a6_50
# AUC_micro                                           [0.9791669449043361]
# average_precision_score_weighted                    [0.9525226776464265]
# f1_score_micro                                      [0.9116843702579667]
# precision_score_micro                               [0.9116843702579667]
# AUC_weighted                                        [0.9434552752909621]
# precision_score_weighted                            [0.9058629036989744]
# f1_score_macro                                      [0.7604744421886932]
# recall_score_macro                                  [0.7418662139458032]
# balanced_accuracy                                   [0.7418662139458032]
# AUC_macro                                            [0.943455275290962]
# average_precision_score_micro                       [0.9801649493283194]
# f1_score_weighted                                   [0.9081611442792707]
# matthews_correlation                                [0.5240377538867557]
# precision_score_macro                               [0.7838506906551768]
# weighted_accuracy                                   [0.9538456249668733]
# average_precision_score_macro                       [0.8129298237558922]
# recall_score_weighted                               [0.9116843702579667]
# norm_macro_recall                                   [0.4837324278916064]
# recall_score_micro                                  [0.9116843702579667]
# accuracy                                            [0.9116843702579667]
# log_loss                                           [0.18083579417439993]
#
# [21 rows x 60 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/92d468e0-d6d8-4216-91b4-0ec68f93c8a6/model_data
# Downloaded azureml/92d468e0-d6d8-4216-91b4-0ec68f93c8a6/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                 silent=None,
#                                                                                                                                 subsample=0.8,
#                                                                                                                                 tree_method='auto',
#                                                                                                                                 verbose=-10,
#                                                                                                                                 verbosity=0))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.14285714285714285,
#                                                                                          0.07142857142857142,
#                                                                                          0.14285714285714285,
#                                                                                          0.35714285714285715,
#                                                                                          0.07142857142857142,
#                                                                                          0.07142857142857142,
#                                                                                          0.07142857142857142,
#                                                                                          0.07142857142857142]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('43',
#                                              Pipeline(memory=None,
#                                                       steps=[('standardscalerwrapper',
#                                                               <azureml.automl.runtime.shared.model_wrappers.StandardScalerWrapper object at 0x7fc7c05b41d0>),
#                                                              ('xgboostclassifier',
#                                                               XGBoostClassifier(base_score=0.5,
#                                                                                 booster='gbtree',
#                                                                                 colsample_bylevel=1,
#                                                                                 colsample_bynode=1,
#                                                                                 colsample_bytree=1,
#                                                                                 e...
#                                                                                 random_state=0,
#                                                                                 reg_alpha=0,
#                                                                                 reg_lambda=0.9375,
#                                                                                 scale_pos_weight=1,
#                                                                                 seed=None,
#                                                                                 silent=None,
#                                                                                 subsample=0.8,
#                                                                                 tree_method='auto',
#                                                                                 verbose=-10,
#                                                                                 verbosity=0))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.14285714285714285, 0.07142857142857142,
#                                          0.14285714285714285, 0.35714285714285715,
#                                          0.07142857142857142, 0.07142857142857142,
#                                          0.07142857142857142,
#                                          0.07142857142857142]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_90577fa0_6a19_11eb_84a1_0303dfe79d29row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_90577fa0_6a19_11eb_84a1_0303dfe79d29row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_90577fa0_6a19_11eb_84a1_0303dfe79d29row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_90577fa0_6a19_11eb_84a1_0303dfe79d29row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_90577fa0_6a19_11eb_84a1_0303dfe79d29" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_90577fa0_6a19_11eb_84a1_0303dfe79d29level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_90577fa0_6a19_11eb_84a1_0303dfe79d29row0_col0" class="data row0 col0" >28796</td>
#                         <td id="T_90577fa0_6a19_11eb_84a1_0303dfe79d29row0_col1" class="data row0 col1" >462</td>
#             </tr>
#             <tr>
#                         <th id="T_90577fa0_6a19_11eb_84a1_0303dfe79d29level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_90577fa0_6a19_11eb_84a1_0303dfe79d29row1_col0" class="data row1 col0" >987</td>
#                         <td id="T_90577fa0_6a19_11eb_84a1_0303dfe79d29row1_col1" class="data row1 col1" >2705</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: 3dfd9d69-295b-41f8-8297-d63fa46e51db,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/9e65f93e-bdd8-437b-b1e8-0647cd6098f7/resourceGroups/aml-quickstarts-138142/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-138142/PipelineRuns/PipelineSubmit/3dfd9d69-295b-41f8-8297-d63fa46e51db)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  35cc3b21-6369-4686-9219-5e5389df5ba0

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
